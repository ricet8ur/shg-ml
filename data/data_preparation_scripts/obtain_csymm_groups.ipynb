# %% [markdown]
# Obtaining a list of centrosymmetric groups.

# %%
# R. W. Boyd: Nonlinear Optics (2008) -> Table 1.5.2
# P. Paufler: Acta Crystallographica Section A (2004) -> space groups list

# ->
centrosymm_space_groups_numbers = (
    [2]
    + list(range(10, 16))
    + list(range(47, 75))
    + list(range(83, 89))
    + list(range(123, 143))
    + list(range(147, 149))
    + list(range(162, 168))
    + list(range(175, 177))
    + list(range(191, 195))
    + list(range(200, 207))
    + list(range(221, 231))
)
len(centrosymm_space_groups_numbers)
# Out:
# 92

# %%
from utils import save_to_json

save_to_json({"group_id": centrosymm_space_groups_numbers}, "../final_data/centrosymmetric.json")
