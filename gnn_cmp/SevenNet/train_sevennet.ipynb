# %%
from sklearn.model_selection import KFold, train_test_split
import time
import orjson
import sys
import shutil
import os.path
import os
import random
import numpy as np
from torch_geometric.loader import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torch.nn as nn
from random import shuffle
from pymatgen.core import Structure
sys.path.append("../../")
from utils.save_and_load import load_from_json, save_to_json
from utils.experiment_tracking import log_mean_std_based_on_test_metrics

# %%
# !pip install -e ./
working_dir = os.getcwd()  # save current path
# Out:
# Obtaining file:///home/danya/mof/shg_ml/gnn_cmp/SevenNet
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: ase in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (3.24.0)
# Requirement already satisfied: braceexpand in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (0.1.7)
# Requirement already satisfied: pyyaml in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (6.0.2)
# Requirement already satisfied: e3nn in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (0.5.4)
# Requirement already satisfied: tqdm in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (4.67.1)
# Requirement already satisfied: scikit-learn in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (1.6.0)
# Requirement already satisfied: torch_geometric>=2.5.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (2.6.1)
# Requirement already satisfied: numpy<2.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (1.26.4)
# Requirement already satisfied: matscipy in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sevenn==0.10.3) (1.1.1)
# Requirement already satisfied: aiohttp in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch_geometric>=2.5.0->sevenn==0.10.3) (3.11.11)
# Requirement already satisfied: fsspec in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch_geometric>=2.5.0->sevenn==0.10.3) (2024.12.0)
# Requirement already satisfied: jinja2 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch_geometric>=2.5.0->sevenn==0.10.3) (3.1.5)
# Requirement already satisfied: psutil>=5.8.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch_geometric>=2.5.0->sevenn==0.10.3) (6.1.1)
# Requirement already satisfied: pyparsing in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch_geometric>=2.5.0->sevenn==0.10.3) (3.2.1)
# Requirement already satisfied: requests in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch_geometric>=2.5.0->sevenn==0.10.3) (2.32.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from ase->sevenn==0.10.3) (1.14.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from ase->sevenn==0.10.3) (3.10.0)
# Requirement already satisfied: sympy in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from e3nn->sevenn==0.10.3) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from e3nn->sevenn==0.10.3) (2.5.1)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from e3nn->sevenn==0.10.3) (0.1.4)
# Requirement already satisfied: packaging in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from matscipy->sevenn==0.10.3) (24.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from scikit-learn->sevenn==0.10.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from scikit-learn->sevenn==0.10.3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from matplotlib>=3.3.4->ase->sevenn==0.10.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from matplotlib>=3.3.4->ase->sevenn==0.10.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from matplotlib>=3.3.4->ase->sevenn==0.10.3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from matplotlib>=3.3.4->ase->sevenn==0.10.3) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from matplotlib>=3.3.4->ase->sevenn==0.10.3) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from matplotlib>=3.3.4->ase->sevenn==0.10.3) (2.9.0.post0)
# Requirement already satisfied: opt-einsum in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from opt-einsum-fx>=0.1.4->e3nn->sevenn==0.10.3) (3.4.0)
# Requirement already satisfied: filelock in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (4.12.2)
# Requirement already satisfied: networkx in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from torch>=1.8.0->e3nn->sevenn==0.10.3) (3.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from sympy->e3nn->sevenn==0.10.3) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from aiohttp->torch_geometric>=2.5.0->sevenn==0.10.3) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from jinja2->torch_geometric>=2.5.0->sevenn==0.10.3) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from requests->torch_geometric>=2.5.0->sevenn==0.10.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from requests->torch_geometric>=2.5.0->sevenn==0.10.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from requests->torch_geometric>=2.5.0->sevenn==0.10.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from requests->torch_geometric>=2.5.0->sevenn==0.10.3) (2024.12.14)
# Requirement already satisfied: six>=1.5 in /home/danya/miniconda3/envs/sevennet/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase->sevenn==0.10.3) (1.17.0)
# Building wheels for collected packages: sevenn
#   Building editable for sevenn (pyproject.toml) ... done
#   Created wheel for sevenn: filename=sevenn-0.10.3-0.editable-py3-none-any.whl size=34166 sha256=0c32cf20b790efc013544821956680f5eda07e1266ceeaa5fabfc90cb654d3c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-trw1urbm/wheels/cd/ea/f2/ea047805855e8039a6d78b61fce4768457fb7dd50dfca0804f
# Successfully built sevenn
# Installing collected packages: sevenn
#   Attempting uninstall: sevenn
#     Found existing installation: sevenn 0.10.3
#     Uninstalling sevenn-0.10.3:
#       Successfully uninstalled sevenn-0.10.3
# Successfully installed sevenn-0.10.3

# %%
import sevenn
sevenn.__version__
# Out:
# '0.10.3'

# %%
import sevenn.util as util
from sevenn.nn.scale import SpeciesWiseRescale
import os
from sevenn.train.graph_dataset import SevenNetGraphDataset

import torch
from ase.build import bulk, molecule

from sevenn.atom_graph_data import AtomGraphData
from sevenn.train.dataload import unlabeled_atoms_to_graph
from sevenn.util import model_from_checkpoint, pretrained_name_to_path
from sevenn.train.trainer import Trainer
import torch.optim.lr_scheduler as scheduler
from copy import deepcopy
from sevenn.error_recorder import ErrorRecorder
from sevenn.train.loss import ScalarLoss
from sevenn.sevenn_logger import Logger
from aim import Run

# %%
# from aim.pytorch import get_model_layers 
from aim import Distribution

# Move tensor from GPU to CPU
def get_pt_tensor(t):
    return t.cpu() if hasattr(t, 'is_cuda') and t.is_cuda else t

def get_model_layers(model, dt, parent_name=None):
    layers = {}
    for name, m in model.named_children():
        layer_name = '{}__{}'.format(parent_name, name) if parent_name else name
        layer_name += '.{}'.format(type(m).__name__)

        if len(list(m.named_children())):
            layers.update(get_model_layers(m, dt, layer_name))
        else:
            layers[layer_name] = {}
            weight = None
            if hasattr(m, 'weight') and m.weight is not None:
                weight = getattr(m.weight, dt, None)
                if weight is not None:
                    layers[layer_name]['weight'] = get_pt_tensor(weight).numpy()

            bias = None
            if hasattr(m, 'bias') and m.bias is not None:
                bias = getattr(m.bias, dt, None)
                if bias is not None:
                    layers[layer_name]['bias'] = get_pt_tensor(bias).numpy()

    return layers

# %%
def finetune(
    from_model_path: str = '7net-0',
    dataset_name: str = 'dataset_of_max_abs_shg',
    random_seed: int = 42,
):
    run = Run(
        experiment=f'SevenNet FT from {from_model_path} on {dataset_name}',
        log_system_params=True,
    )

    dataset_shg = load_from_json(f'../../data/final_data/{dataset_name}.json')

    sevennet_0_cp_path = util.pretrained_name_to_path(from_model_path)
    model, config = util.model_from_checkpoint(sevennet_0_cp_path)
    cutoff = config['cutoff']  # 7net-0 uses 5.0 Angstrom cutoff

    dataset = [
        AtomGraphData.from_numpy_dict(
            dict(
                **unlabeled_atoms_to_graph(
                    atoms=Structure.from_dict(v['structure']).to_ase_atoms(),
                    cutoff=cutoff,
                ),
                total_energy=v['shg'],
                crystal_idx=idx,
            )
        )
        for idx, (k, v) in enumerate(dataset_shg.items())
    ]

    dataset_keys = [k for k, v in dataset_shg.items()]
    print(f'# graphs: {len(dataset)}')
    print(dataset[0])

    # enable deterministic learning
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True)
    random.seed(random_seed)
    np.random.seed(random_seed)
    # %env CUBLAS_WORKSPACE_CONFIG=:4096:8

    k_folds = 10
    kfold = KFold(n_splits=k_folds, shuffle=True, random_state=random_seed)
    data_range = np.arange(0, len(dataset))

    fold_partition = {}
    fold_partition_names = {}
    crystal_predictions_log_for_all_folds = {}
    run.set_artifacts_uri(f'file://{os.getcwd()}/artifacts/')
    for fold, (train_val_idx, test_idx) in enumerate(kfold.split(data_range)):
        print(f'FOLD {fold}')

        train_idx, val_idx = train_test_split(
            train_val_idx, train_size=8 / 9, random_state=random_seed
        )
        g = torch.manual_seed(random_seed)

        print(f'# graphs for training: {len(train_idx)}')
        print(f'# graphs for validation: {len(val_idx)}')

        # log fold partition
        fold_partition = dict(
            fold=fold_partition.get('fold', {})
            | {
                fold: dict(
                    train_idx=train_idx.tolist(),
                    val_idx=val_idx.tolist(),
                    test_idx=test_idx.tolist(),
                )
            }
        )
        fold_partition_names = dict(
            fold=fold_partition_names.get('fold', {})
            | {
                fold: dict(
                    train_names=[dataset_keys[x] for x in train_idx.tolist()],
                    val_names=[dataset_keys[x] for x in val_idx.tolist()],
                    test_names=[dataset_keys[x] for x in test_idx.tolist()],
                )
            }
        )

        # log dataset once for all folds
        dataset_key_target = {
            dataset_keys[idx]: v['total_energy'].data.cpu().item()
            for idx, v in enumerate(dataset)
        }
        dataset_key_index = {
            dataset_keys[idx]: v['total_energy'].data.cpu().item()
            for idx, v in enumerate(dataset)
        }
        dataset_index_key_target = {
            idx: dict(
                target=v['total_energy'].data.cpu().item(), key=dataset_keys[idx]
            )
            for idx, v in enumerate(dataset)
        }
        # run['dataset_index_key_target'] = dataset_index_key_target

        hparams = dict(
            rescale_atomic_energy=True, all_requires_grad=True, batch_size=1
        )
        train_loader = DataLoader(
            dataset,
            batch_size=hparams['batch_size'],
            # shuffle=True,
            sampler=SubsetRandomSampler(train_idx, g),
        )
        valid_loader = DataLoader(
            dataset,
            sampler=SubsetRandomSampler(val_idx, g),
        )
        test_loader = DataLoader(
            dataset,
            sampler=SubsetRandomSampler(test_idx, g),
        )

        sevennet_0_cp_path = util.pretrained_name_to_path(from_model_path)
        model, config = util.model_from_checkpoint(sevennet_0_cp_path)

        run['hparams'] = hparams
        # set all params to trainable
        if hparams['all_requires_grad']:
            for param in model.parameters():
                param.requires_grad = True
            for module in model.modules():
                for param in module.parameters():
                    param.requires_grad = True
            for name, module in model.named_children():
                for param in module.parameters():
                    param.requires_grad = True
                    for sub_name, sub_module in module.named_children():
                        for p in sub_module.parameters():
                            p.requires_grad = True

        # To enhance training speed, we will overwrite shift scale module to trainable
        # By making energy shift trainable, error quickly converges.
        shift_scale_module = model._modules['rescale_atomic_energy']
        shift = shift_scale_module.shift.tolist()
        scale = shift_scale_module.scale.tolist()
        model._modules['rescale_atomic_energy'] = SpeciesWiseRescale(
            shift=shift,
            scale=scale,
            train_shift_scale=hparams['rescale_atomic_energy'],
        )

        for name, module in model.named_children():
            print(
                f'Layer: {name}, Type: {type(module).__name__}, Requires Grad: {any(p.requires_grad for p in module.parameters())}'
            )
            for sub_name, sub_module in module.named_children():
                print(
                    f'  Sub-layer: {sub_name}, Type: {type(sub_module).__name__}, Requires Grad: {any(p.requires_grad for p in sub_module.parameters())}'
                )

        run['model_parameters_count'] = sum(p.numel() for p in model.parameters())
        run['model_trainable_parameters_count'] = sum(
            p.numel() for p in model.parameters() if p.requires_grad
        )
        print(model)
        cutoff = config['cutoff']  # 7net-0 uses 5.0 Angstrom cutoff

        # print(train_loader[0])

        total_epoch = 40
        config.update(
            {
                'optimizer': 'adam',
                'optim_param': {'lr': 0.01},
                'scheduler': 'linearlr',
                'scheduler_param': {
                    'start_factor': 1.0,
                    'total_iters': total_epoch,
                    'end_factor': 0.1,
                },
                'is_ddp': False,  # 7net-0 was traied with ddp=True.
                # 'loss': 'L1',
                # 'loss_param': dict(),
            }
        )
        # print(config)
        run['config'] = {
            k: v.tolist()
            if isinstance(v, np.ndarray)
            else str(v)
            if isinstance(v, torch.device)
            else v
            for k, v in config.items()
        }
        trainer = Trainer.from_config(model, config)
        trainer.run = run
        trainer.fold = fold
        loss = ScalarLoss()
        # loss.assign_criteria(nn.L1Loss())
        loss.assign_criteria(nn.HuberLoss())
        trainer.loss_functions = [(loss, 1.0)]

        # We will use it as it is, with loss weight: 1.0, 1.0, and 0.01 for energy, force, and stress, respectively.
        print(trainer.loss_functions)
        print(trainer.optimizer)
        print(trainer.scheduler)
        train_recorder = ErrorRecorder.from_config(config)
        valid_recorder = deepcopy(train_recorder)
        choosen_metrics = []
        for metric in train_recorder.metrics:
            print(metric)
            if 'energy' in str(metric.name).lower():
                print('energy in ', str(metric.name).lower())
                choosen_metrics.append(metric)
        print('Choosen metrics:')
        for metric in choosen_metrics:
            print(metric)
        train_recorder.metrics = choosen_metrics
        valid_recorder = deepcopy(train_recorder)
        test_recorder = deepcopy(train_recorder)

        valid_best = float('inf')

        logger = Logger()
        logger.screen = True
        with logger:
            t = time.time()
            for epoch in range(1, total_epoch + 1):
                logger.timer_start('epoch')
                logger.writeline(
                    f'Epoch {epoch}/{total_epoch}  Learning rate: {trainer.get_lr():.6f}'
                )
                trainer.run_one_epoch(
                    train_loader,
                    is_train=True,
                    error_recorder=train_recorder,
                    epoch=epoch,
                    subset='train',
                )
                trainer.run_one_epoch(
                    valid_loader,
                    is_train=False,
                    error_recorder=valid_recorder,
                    epoch=epoch,
                    subset='val',
                )
                trainer.scheduler_step()
                train_err = train_recorder.epoch_forward()
                # return averaged error over one epoch, then reset.
                valid_err = valid_recorder.epoch_forward()
                logger.bar()
                logger.write_full_table([train_err, valid_err], ['Train', 'Valid'])
                logger.timer_end('epoch', message=f'Epoch {epoch} elapsed')

                # grad_hist = get_model_layers(model, 'grad')

                # for name, params in grad_hist.items():
                #     if 'weight' in params:
                #         run.track(
                #             Distribution(params['weight']),
                #             name=name,
                #             context={
                #                 'type': 'gradients',
                #                 'params': 'weights',
                #                 'fold': fold,
                #             },
                #         )
                #     if 'bias' in params:
                #         run.track(
                #             Distribution(params['bias']),
                #             name=name,
                #             context={
                #                 'type': 'gradients',
                #                 'params': 'biases',
                #                 'fold': fold,
                #             },
                #         )
            run.track(time.time() - t, name='train_time', context={'fold': fold})
            t = time.time()
            trainer.run_one_epoch(
                test_loader,
                is_train=False,
                error_recorder=test_recorder,
                subset='test',
            )
            run.track(time.time() - t, name='test_time', context={'fold': fold})
            test_err = test_recorder.epoch_forward()
            logger.bar()
            logger.write_full_table([test_err], ['Test'])

        crystal_predictions_log_for_all_folds = dict(
            fold=crystal_predictions_log_for_all_folds.get('fold', {})
            | {fold: trainer.crystal_predictions_log.copy()}
        )
    trainer.write_checkpoint(
        os.path.join(working_dir, 'checkpoint_fine_tuned.pth'),
        config=config,
        epoch=total_epoch,
    )

    log_mean_std_based_on_test_metrics(run)
    jsons_to_log = dict(
        fold_partition=fold_partition,
        fold_partition_names=fold_partition_names,
        dataset_key_target=dataset_key_target,
        dataset_key_index=dataset_key_index,
        dataset_index_key_target=dataset_index_key_target,
        crystal_predictions_log_for_all_folds=crystal_predictions_log_for_all_folds,
    )
    json_name = 'train_info.json'
    save_to_json(jsons_to_log, json_name)
    run.log_artifact(json_name)
    # os.makedirs("trained", exist_ok=True)
    # os.makedirs(f"trained/{ds_name}", exist_ok=True)
    run.close()

# %%
# finetune()

# %%
# finetune('7net-l3i5')

# %%
finetune(dataset_name='base_dataset_of_eff_shg')
# Out:
# # graphs: 974
# AtomGraphData(
#   x=[24],
#   edge_index=[2, 756],
#   pos=[24, 3],
#   node_attr=[24],
#   atomic_numbers=[24],
#   edge_vec=[756, 3],
#   cell_lattice_vectors=[3, 3],
#   pbc_shift=[756, 3],
#   cell_volume=404.682861328125,
#   num_atoms=24,
#   data_info={},
#   total_energy=0.33507025241851807,
#   crystal_idx=0
# )
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8
# FOLD 0
# # graphs for training: 778
# # graphs for validation: 98
# Layer: edge_embedding, Type: EdgeEmbedding, Requires Grad: True
#   Sub-layer: basis_function, Type: BesselBasis, Requires Grad: True
#   Sub-layer: cutoff_function, Type: XPLORCutoff, Requires Grad: False
#   Sub-layer: spherical, Type: SphericalEncoding, Requires Grad: False
# Layer: onehot_idx_to_onehot, Type: OnehotEmbedding, Requires Grad: False
# Layer: onehot_to_feature_x, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 0_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 0_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 1_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 1_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 1_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 1_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 1_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 1_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 2_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 2_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 2_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 2_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 2_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 2_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 3_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 3_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 3_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 3_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 3_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 3_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 4_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 4_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 4_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 4_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 4_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 4_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: reduce_input_to_hidden, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: reduce_hidden_to_energy, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: rescale_atomic_energy, Type: SpeciesWiseRescale, Requires Grad: True
# Layer: reduce_total_enegy, Type: AtomReduce, Requires Grad: False
# Layer: force_output, Type: ForceStressOutputFromEdge, Requires Grad: False
# AtomGraphSequential(
#   (edge_embedding): EdgeEmbedding(
#     (basis_function): BesselBasis()
#     (cutoff_function): XPLORCutoff()
#     (spherical): SphericalEncoding(
#       (sph): SphericalHarmonics()
#     )
#   )
#   (onehot_idx_to_onehot): OnehotEmbedding()
#   (onehot_to_feature_x): IrrepsLinear(
#     (linear): Linear(89x0e -> 128x0e | 11392 weights)
#   )
#   (0_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e -> 224x0e+64x1e+32x2e | 28672 weights)
#   )
#   (0_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e -> 128x0e | 16384 weights)
#   )
#   (0_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e x 1x0e+1x1e+1x2e -> 128x0e+128x1e+128x2e | 384 paths | 384 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 384]
#   )
#   (0_self_interaction_2): IrrepsLinear(
#     (linear): Linear(128x0e+128x1e+128x2e -> 224x0e+64x1e+32x2e | 40960 weights)
#   )
#   (0_self_connection_outro): SelfConnectionOutro()
#   (0_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (1_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (1_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (1_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (1_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (1_self_connection_outro): SelfConnectionOutro()
#   (1_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (2_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (2_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (2_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (2_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (2_self_connection_outro): SelfConnectionOutro()
#   (2_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (3_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (3_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (3_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (3_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (3_self_connection_outro): SelfConnectionOutro()
#   (3_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (4_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e | 16384 weights)
#   )
#   (4_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (4_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e | 224 paths | 224 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 224]
#   )
#   (4_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e -> 128x0e | 28672 weights)
#   )
#   (4_self_connection_outro): SelfConnectionOutro()
#   (4_equivariant_gate): EquivariantGate(
#     (gate): Gate (128x0e -> 128x0e)
#   )
#   (reduce_input_to_hidden): IrrepsLinear(
#     (linear): Linear(128x0e -> 64x0e | 8192 weights)
#   )
#   (reduce_hidden_to_energy): IrrepsLinear(
#     (linear): Linear(64x0e -> 1x0e | 64 weights)
#   )
#   (rescale_atomic_energy): SpeciesWiseRescale()
#   (reduce_total_enegy): AtomReduce()
#   (force_output): ForceStressOutputFromEdge()
# )
# [(Energy, 1.0)]
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     weight_decay: 0
# )
# <torch.optim.lr_scheduler.LinearLR object at 0x7a8d69c18070>
# Energy_RMSE (eV/atom): nan
# energy in  energy_rmse
# Force_RMSE (eV/Å): nan
# Stress_RMSE (kbar): nan
# Energy_MAE (eV/atom): nan
# energy in  energy_mae
# Force_MAE (eV/Å): nan
# Stress_MAE (kbar): nan
# Energy_Loss: nan
# energy in  energy_loss
# Force_Loss: nan
# Stress_Loss: nan
# TotalLoss: nan
# Choosen metrics:
# Energy_RMSE (eV/atom): nan
# Energy_MAE (eV/atom): nan
# Energy_Loss: nan
# Epoch 1/40  Learning rate: 0.010000
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train              74.053104               5.616052      0.056111
# Valid               9.482908               2.792516      0.027875
# Epoch 1 elapsed: 0:01:17.08
# Epoch 2/40  Learning rate: 0.009775
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               6.889565               2.045141      0.020402
# Valid               9.545113               2.845764      0.028408
# Epoch 2 elapsed: 0:01:15.92
# Epoch 3/40  Learning rate: 0.009550
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               6.451435               1.802884      0.017979
# Valid               9.164210               2.731960      0.027270
# Epoch 3 elapsed: 0:01:16.01
# Epoch 4/40  Learning rate: 0.009325
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               6.336866               1.762374      0.017574
# Valid               8.986106               2.558347      0.025534
# Epoch 4 elapsed: 0:01:15.93
# Epoch 5/40  Learning rate: 0.009100
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.991868               1.627544      0.016226
# Valid               9.062811               2.537566      0.025326
# Epoch 5 elapsed: 0:01:16.02
# Epoch 6/40  Learning rate: 0.008875
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.605407               1.511034      0.015061
# Valid               8.855631               2.579973      0.025750
# Epoch 6 elapsed: 0:01:15.98
# Epoch 7/40  Learning rate: 0.008650
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.651295               1.473942      0.014690
# Valid               8.520003               2.295468      0.022905
# Epoch 7 elapsed: 0:01:15.97
# Epoch 8/40  Learning rate: 0.008425
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.345684               1.385042      0.013801
# Valid               8.691879               2.562287      0.025575
# Epoch 8 elapsed: 0:01:16.06
# Epoch 9/40  Learning rate: 0.008200
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.391538               1.379648      0.013747
# Valid               8.127291               2.342508      0.023376
# Epoch 9 elapsed: 0:01:16.06
# Epoch 10/40  Learning rate: 0.007975
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.220274               1.335406      0.013304
# Valid               8.082793               2.200172      0.021953
# Epoch 10 elapsed: 0:01:16.15
# Epoch 11/40  Learning rate: 0.007750
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.257797               1.310710      0.013057
# Valid               8.936807               2.595336      0.025903
# Epoch 11 elapsed: 0:01:15.85
# Epoch 12/40  Learning rate: 0.007525
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.033206               1.206033      0.012011
# Valid               7.980805               2.094907      0.020901
# Epoch 12 elapsed: 0:01:16.07
# Epoch 13/40  Learning rate: 0.007300
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.297769               1.315526      0.013106
# Valid               8.194891               2.182838      0.021781
# Epoch 13 elapsed: 0:01:16.13
# Epoch 14/40  Learning rate: 0.007075
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.038536               1.249309      0.012444
# Valid               7.921298               2.069657      0.020647
# Epoch 14 elapsed: 0:01:16.11
# Epoch 15/40  Learning rate: 0.006850
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.655332               1.346266      0.013413
# Valid               8.388174               2.318548      0.023135
# Epoch 15 elapsed: 0:01:16.05
# Epoch 16/40  Learning rate: 0.006625
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.105217               1.282464      0.012775
# Valid               8.418427               2.351243      0.023463
# Epoch 16 elapsed: 0:01:16.01
# Epoch 17/40  Learning rate: 0.006400
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.965889               1.207266      0.012023
# Valid               8.119026               2.140853      0.021359
# Epoch 17 elapsed: 0:01:16.07
# Epoch 18/40  Learning rate: 0.006175
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               6.044761               1.324217      0.013192
# Valid               8.548314               2.611952      0.026070
# Epoch 18 elapsed: 0:01:16.03
# Epoch 19/40  Learning rate: 0.005950
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.862323               1.150766      0.011458
# Valid               8.238423               2.162440      0.021575
# Epoch 19 elapsed: 0:01:16.02
# Epoch 20/40  Learning rate: 0.005725
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.812144               1.127718      0.011228
# Valid               8.476807               2.219630      0.022147
# Epoch 20 elapsed: 0:01:15.92
# Epoch 21/40  Learning rate: 0.005500
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.346382               1.272059      0.012671
# Valid               8.375071               2.222453      0.022177
# Epoch 21 elapsed: 0:01:15.95
# Epoch 22/40  Learning rate: 0.005275
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.370522               1.037168      0.010322
# Valid               7.927777               2.196295      0.021913
# Epoch 22 elapsed: 0:01:15.94
# Epoch 23/40  Learning rate: 0.005050
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               6.174532               1.297561      0.012926
# Valid               8.597121               2.562614      0.025576
# Epoch 23 elapsed: 0:01:16.10
# Epoch 24/40  Learning rate: 0.004825
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.708555               1.082940      0.010780
# Valid               8.137445               2.125976      0.021210
# Epoch 24 elapsed: 0:01:15.92
# Epoch 25/40  Learning rate: 0.004600
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.377750               1.035009      0.010301
# Valid               8.586996               2.330172      0.023253
# Epoch 25 elapsed: 0:01:15.93
# Epoch 26/40  Learning rate: 0.004375
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.085008               1.000738      0.009958
# Valid               7.992373               2.066542      0.020616
# Epoch 26 elapsed: 0:01:15.97
# Epoch 27/40  Learning rate: 0.004150
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.605727               1.049875      0.010450
# Valid               8.491490               2.251036      0.022462
# Epoch 27 elapsed: 0:01:15.97
# Epoch 28/40  Learning rate: 0.003925
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.626409               1.023293      0.010184
# Valid               8.133816               2.236357      0.022314
# Epoch 28 elapsed: 0:01:16.13
# Epoch 29/40  Learning rate: 0.003700
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.570734               0.997291      0.009924
# Valid               7.975621               2.020836      0.020161
# Epoch 29 elapsed: 0:01:15.79
# Epoch 30/40  Learning rate: 0.003475
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.508886               0.959628      0.009548
# Valid               8.164860               2.123055      0.021182
# Epoch 30 elapsed: 0:01:15.85
# Epoch 31/40  Learning rate: 0.003250
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.491342               0.963459      0.009585
# Valid               8.149735               2.164711      0.021599
# Epoch 31 elapsed: 0:01:15.97
# Epoch 32/40  Learning rate: 0.003025
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.409678               0.944104      0.009393
# Valid               8.378057               2.256868      0.022521
# Epoch 32 elapsed: 0:01:16.00
# Epoch 33/40  Learning rate: 0.002800
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.867565               1.012771      0.010079
# Valid               7.875106               2.151304      0.021463
# Epoch 33 elapsed: 0:01:15.88
# Epoch 34/40  Learning rate: 0.002575
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.367182               0.884907      0.008800
# Valid               7.762305               2.062832      0.020579
# Epoch 34 elapsed: 0:01:15.81
# Epoch 35/40  Learning rate: 0.002350
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.132943               0.815807      0.008110
# Valid               7.871977               2.042625      0.020378
# Epoch 35 elapsed: 0:01:15.90
# Epoch 36/40  Learning rate: 0.002125
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.008514               0.820828      0.008160
# Valid               7.830122               2.075001      0.020702
# Epoch 36 elapsed: 0:01:15.90
# Epoch 37/40  Learning rate: 0.001900
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               3.953450               0.781410      0.007766
# Valid               7.682540               2.058175      0.020534
# Epoch 37 elapsed: 0:01:15.83
# Epoch 38/40  Learning rate: 0.001675
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               3.847683               0.717629      0.007129
# Valid               7.589034               2.015317      0.020105
# Epoch 38 elapsed: 0:01:16.03
# Epoch 39/40  Learning rate: 0.001450
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               3.817325               0.703363      0.006985
# Valid               7.776599               2.082966      0.020781
# Epoch 39 elapsed: 0:01:16.01
# Epoch 40/40  Learning rate: 0.001225
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train              17.370563               1.253004      0.012482
# Valid               7.722340               2.049913      0.020450
# Epoch 40 elapsed: 0:01:16.01
# ------------------------------------------------------------------------------------------------------------------------
#       Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# ------------------------------------------------------------------
# Test               2.001682               0.722162      0.007172
# FOLD 1
# # graphs for training: 778
# # graphs for validation: 98
# Layer: edge_embedding, Type: EdgeEmbedding, Requires Grad: True
#   Sub-layer: basis_function, Type: BesselBasis, Requires Grad: True
#   Sub-layer: cutoff_function, Type: XPLORCutoff, Requires Grad: False
#   Sub-layer: spherical, Type: SphericalEncoding, Requires Grad: False
# Layer: onehot_idx_to_onehot, Type: OnehotEmbedding, Requires Grad: False
# Layer: onehot_to_feature_x, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 0_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 0_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 0_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 1_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 1_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 1_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 1_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 1_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 1_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 2_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 2_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 2_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 2_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 2_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 2_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 3_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 3_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 3_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 3_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 3_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 3_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: 4_self_connection_intro, Type: SelfConnectionLinearIntro, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 4_self_interaction_1, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 4_convolution, Type: IrrepsConvolution, Requires Grad: True
#   Sub-layer: convolution, Type: TensorProduct, Requires Grad: False
#   Sub-layer: weight_nn, Type: FullyConnectedNet, Requires Grad: True
# Layer: 4_self_interaction_2, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: 4_self_connection_outro, Type: SelfConnectionOutro, Requires Grad: False
# Layer: 4_equivariant_gate, Type: EquivariantGate, Requires Grad: False
#   Sub-layer: gate, Type: Gate, Requires Grad: False
# Layer: reduce_input_to_hidden, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: reduce_hidden_to_energy, Type: IrrepsLinear, Requires Grad: True
#   Sub-layer: linear, Type: Linear, Requires Grad: True
# Layer: rescale_atomic_energy, Type: SpeciesWiseRescale, Requires Grad: True
# Layer: reduce_total_enegy, Type: AtomReduce, Requires Grad: False
# Layer: force_output, Type: ForceStressOutputFromEdge, Requires Grad: False
# AtomGraphSequential(
#   (edge_embedding): EdgeEmbedding(
#     (basis_function): BesselBasis()
#     (cutoff_function): XPLORCutoff()
#     (spherical): SphericalEncoding(
#       (sph): SphericalHarmonics()
#     )
#   )
#   (onehot_idx_to_onehot): OnehotEmbedding()
#   (onehot_to_feature_x): IrrepsLinear(
#     (linear): Linear(89x0e -> 128x0e | 11392 weights)
#   )
#   (0_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e -> 224x0e+64x1e+32x2e | 28672 weights)
#   )
#   (0_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e -> 128x0e | 16384 weights)
#   )
#   (0_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e x 1x0e+1x1e+1x2e -> 128x0e+128x1e+128x2e | 384 paths | 384 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 384]
#   )
#   (0_self_interaction_2): IrrepsLinear(
#     (linear): Linear(128x0e+128x1e+128x2e -> 224x0e+64x1e+32x2e | 40960 weights)
#   )
#   (0_self_connection_outro): SelfConnectionOutro()
#   (0_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (1_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (1_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (1_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (1_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (1_self_connection_outro): SelfConnectionOutro()
#   (1_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (2_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (2_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (2_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (2_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (2_self_connection_outro): SelfConnectionOutro()
#   (2_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (3_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 224x0e+64x1e+32x2e | 33792 weights)
#   )
#   (3_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (3_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e+384x1e+352x2e | 960 paths | 960 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 960]
#   )
#   (3_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e+384x1e+352x2e -> 224x0e+64x1e+32x2e | 86016 weights)
#   )
#   (3_self_connection_outro): SelfConnectionOutro()
#   (3_equivariant_gate): EquivariantGate(
#     (gate): Gate (224x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e)
#   )
#   (4_self_connection_intro): SelfConnectionLinearIntro(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e | 16384 weights)
#   )
#   (4_self_interaction_1): IrrepsLinear(
#     (linear): Linear(128x0e+64x1e+32x2e -> 128x0e+64x1e+32x2e | 21504 weights)
#   )
#   (4_convolution): IrrepsConvolution(
#     (convolution): TensorProduct(128x0e+64x1e+32x2e x 1x0e+1x1e+1x2e -> 224x0e | 224 paths | 224 weights)
#     (weight_nn): FullyConnectedNet[8, 64, 64, 224]
#   )
#   (4_self_interaction_2): IrrepsLinear(
#     (linear): Linear(224x0e -> 128x0e | 28672 weights)
#   )
#   (4_self_connection_outro): SelfConnectionOutro()
#   (4_equivariant_gate): EquivariantGate(
#     (gate): Gate (128x0e -> 128x0e)
#   )
#   (reduce_input_to_hidden): IrrepsLinear(
#     (linear): Linear(128x0e -> 64x0e | 8192 weights)
#   )
#   (reduce_hidden_to_energy): IrrepsLinear(
#     (linear): Linear(64x0e -> 1x0e | 64 weights)
#   )
#   (rescale_atomic_energy): SpeciesWiseRescale()
#   (reduce_total_enegy): AtomReduce()
#   (force_output): ForceStressOutputFromEdge()
# )
# [(Energy, 1.0)]
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.01
#     lr: 0.01
#     maximize: False
#     weight_decay: 0
# )
# <torch.optim.lr_scheduler.LinearLR object at 0x7a8d5a9d89d0>
# Energy_RMSE (eV/atom): nan
# energy in  energy_rmse
# Force_RMSE (eV/Å): nan
# Stress_RMSE (kbar): nan
# Energy_MAE (eV/atom): nan
# energy in  energy_mae
# Force_MAE (eV/Å): nan
# Stress_MAE (kbar): nan
# Energy_Loss: nan
# energy in  energy_loss
# Force_Loss: nan
# Stress_Loss: nan
# TotalLoss: nan
# Choosen metrics:
# Energy_RMSE (eV/atom): nan
# Energy_MAE (eV/atom): nan
# Energy_Loss: nan
# Epoch 1/40  Learning rate: 0.010000
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               7.064391               2.275208      0.022702
# Valid               9.043296               2.614056      0.026091
# Epoch 1 elapsed: 0:01:17.01
# Epoch 2/40  Learning rate: 0.009775
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               6.027471               1.773103      0.017681
# Valid               9.296839               3.182652      0.031777
# Epoch 2 elapsed: 0:01:16.96
# Epoch 3/40  Learning rate: 0.009550
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.812112               1.675189      0.016702
# Valid               8.908273               2.365583      0.023606
# Epoch 3 elapsed: 0:01:16.96
# Epoch 4/40  Learning rate: 0.009325
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.765462               1.558857      0.015539
# Valid               8.952049               2.311319      0.023063
# Epoch 4 elapsed: 0:01:16.97
# Epoch 5/40  Learning rate: 0.009100
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.528973               1.508471      0.015035
# Valid               8.726903               2.210539      0.022056
# Epoch 5 elapsed: 0:01:16.99
# Epoch 6/40  Learning rate: 0.008875
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.232555               1.463558      0.014586
# Valid               8.762306               2.453284      0.024483
# Epoch 6 elapsed: 0:01:16.89
# Epoch 7/40  Learning rate: 0.008650
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.253835               1.345002      0.013401
# Valid               9.746480               2.789972      0.027850
# Epoch 7 elapsed: 0:01:16.93
# Epoch 8/40  Learning rate: 0.008425
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.904243               1.343750      0.013388
# Valid               8.541564               2.317839      0.023129
# Epoch 8 elapsed: 0:01:16.96
# Epoch 9/40  Learning rate: 0.008200
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.886562               1.300473      0.012955
# Valid               8.580124               2.242762      0.022379
# Epoch 9 elapsed: 0:01:16.94
# Epoch 10/40  Learning rate: 0.007975
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.049090               1.306998      0.013021
# Valid               8.662531               2.195219      0.021904
# Epoch 10 elapsed: 0:01:16.96
# Epoch 11/40  Learning rate: 0.007750
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.720343               1.185751      0.011808
# Valid               8.910851               2.399897      0.023949
# Epoch 11 elapsed: 0:01:16.98
# Epoch 12/40  Learning rate: 0.007525
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.675310               1.189294      0.011843
# Valid               8.785766               2.118011      0.021131
# Epoch 12 elapsed: 0:01:16.89
# Epoch 13/40  Learning rate: 0.007300
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.815702               1.238739      0.012338
# Valid               8.913534               2.213285      0.022083
# Epoch 13 elapsed: 0:01:17.02
# Epoch 14/40  Learning rate: 0.007075
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.607512               1.136601      0.011317
# Valid               9.044717               2.442765      0.024378
# Epoch 14 elapsed: 0:01:17.04
# Epoch 15/40  Learning rate: 0.006850
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.446186               1.077076      0.010722
# Valid               8.815394               2.383178      0.023782
# Epoch 15 elapsed: 0:01:17.16
# Epoch 16/40  Learning rate: 0.006625
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.845075               1.170734      0.011658
# Valid               8.746894               2.196158      0.021913
# Epoch 16 elapsed: 0:01:17.17
# Epoch 17/40  Learning rate: 0.006400
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.271487               1.290075      0.012851
# Valid               8.781268               2.292503      0.022876
# Epoch 17 elapsed: 0:01:17.20
# Epoch 18/40  Learning rate: 0.006175
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.306347               1.045482      0.010406
# Valid               8.823282               2.238486      0.022335
# Epoch 18 elapsed: 0:01:17.12
# Epoch 19/40  Learning rate: 0.005950
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train             258.033459              10.296309      0.102914
# Valid               8.891793               2.271553      0.022666
# Epoch 19 elapsed: 0:01:17.15
# Epoch 20/40  Learning rate: 0.005725
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.258865               1.046403      0.010415
# Valid               9.003602               2.488674      0.024837
# Epoch 20 elapsed: 0:01:17.14
# Epoch 21/40  Learning rate: 0.005500
# ...
# Train               6.461224               1.619872      0.016149
# Valid               2.888164               1.144200      0.011392
# Epoch 6 elapsed: 0:01:15.71
# Epoch 7/40  Learning rate: 0.008650
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.153678               1.331960      0.013270
# Valid               3.334730               1.129298      0.011244
# Epoch 7 elapsed: 0:01:15.81
# Epoch 8/40  Learning rate: 0.008425
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.472061               1.396053      0.013911
# Valid               2.994032               1.068932      0.010640
# Epoch 8 elapsed: 0:01:15.86
# Epoch 9/40  Learning rate: 0.008200
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.632781               1.382465      0.013775
# Valid               2.759981               1.016333      0.010114
# Epoch 9 elapsed: 0:01:15.84
# Epoch 10/40  Learning rate: 0.007975
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.145165               1.276566      0.012716
# Valid               3.225263               1.167264      0.011623
# Epoch 10 elapsed: 0:01:15.85
# Epoch 11/40  Learning rate: 0.007750
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.226935               1.315672      0.013107
# Valid               3.799748               1.291008      0.012861
# Epoch 11 elapsed: 0:01:15.88
# Epoch 12/40  Learning rate: 0.007525
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.226813               1.269662      0.012647
# Valid               2.786372               1.039042      0.010341
# Epoch 12 elapsed: 0:01:15.80
# Epoch 13/40  Learning rate: 0.007300
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.996128               1.220860      0.012159
# Valid               3.533082               1.163770      0.011589
# Epoch 13 elapsed: 0:01:15.80
# Epoch 14/40  Learning rate: 0.007075
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.014242               1.199983      0.011951
# Valid               3.605275               1.259156      0.012542
# Epoch 14 elapsed: 0:01:15.78
# Epoch 15/40  Learning rate: 0.006850
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.141871               1.244283      0.012393
# Valid               2.860496               1.203026      0.011980
# Epoch 15 elapsed: 0:01:15.75
# Epoch 16/40  Learning rate: 0.006625
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.865748               1.154894      0.011500
# Valid               2.504057               0.941199      0.009363
# Epoch 16 elapsed: 0:01:16.15
# Epoch 17/40  Learning rate: 0.006400
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.966403               1.145578      0.011406
# Valid               2.713350               1.032057      0.010271
# Epoch 17 elapsed: 0:01:16.16
# Epoch 18/40  Learning rate: 0.006175
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.952569               1.132846      0.011279
# Valid               2.960151               1.067119      0.010622
# Epoch 18 elapsed: 0:01:16.18
# Epoch 19/40  Learning rate: 0.005950
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.926478               1.173407      0.011685
# Valid               2.526542               0.937473      0.009325
# Epoch 19 elapsed: 0:01:16.10
# Epoch 20/40  Learning rate: 0.005725
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.756862               1.064320      0.010594
# Valid               2.517274               0.813587      0.008087
# Epoch 20 elapsed: 0:01:15.95
# Epoch 21/40  Learning rate: 0.005500
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.726758               1.028005      0.010231
# Valid               2.531838               0.968930      0.009640
# Epoch 21 elapsed: 0:01:15.91
# Epoch 22/40  Learning rate: 0.005275
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.598869               1.054566      0.010496
# Valid               2.666391               1.130800      0.011258
# Epoch 22 elapsed: 0:01:15.98
# Epoch 23/40  Learning rate: 0.005050
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.799444               1.035160      0.010303
# Valid               2.720044               0.953354      0.009485
# Epoch 23 elapsed: 0:01:16.18
# Epoch 24/40  Learning rate: 0.004825
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.720826               1.058644      0.010537
# Valid               2.447469               0.888815      0.008839
# Epoch 24 elapsed: 0:01:16.06
# Epoch 25/40  Learning rate: 0.004600
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.417402               0.940494      0.009356
# Valid               2.346634               0.885452      0.008805
# Epoch 25 elapsed: 0:01:16.12
# Epoch 26/40  Learning rate: 0.004375
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.502995               0.982614      0.009778
# Valid               3.092272               1.085249      0.010804
# Epoch 26 elapsed: 0:01:16.18
# Epoch 27/40  Learning rate: 0.004150
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               5.333112               1.050822      0.010460
# Valid               2.461745               0.903547      0.008987
# Epoch 27 elapsed: 0:01:16.12
# Epoch 28/40  Learning rate: 0.003925
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.468424               0.927655      0.009228
# Valid               2.239715               0.825797      0.008209
# Epoch 28 elapsed: 0:01:15.99
# Epoch 29/40  Learning rate: 0.003700
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.721389               0.955584      0.009507
# Valid               2.178458               0.796070      0.007913
# Epoch 29 elapsed: 0:01:15.88
# Epoch 30/40  Learning rate: 0.003475
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.431395               0.914252      0.009094
# Valid               2.024127               0.705323      0.007007
# Epoch 30 elapsed: 0:01:15.90
# Epoch 31/40  Learning rate: 0.003250
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.334608               0.892569      0.008878
# Valid               2.314884               0.851501      0.008467
# Epoch 31 elapsed: 0:01:15.89
# Epoch 32/40  Learning rate: 0.003025
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.379999               0.854339      0.008495
# Valid               2.186941               0.813353      0.008084
# Epoch 32 elapsed: 0:01:16.05
# Epoch 33/40  Learning rate: 0.002800
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train              15.964427               1.396545      0.013916
# Valid               2.398136               0.845556      0.008407
# Epoch 33 elapsed: 0:01:16.11
# Epoch 34/40  Learning rate: 0.002575
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.415200               0.840607      0.008358
# Valid               2.453655               0.872044      0.008672
# Epoch 34 elapsed: 0:01:16.18
# Epoch 35/40  Learning rate: 0.002350
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.405206               0.824825      0.008200
# Valid               2.365142               0.826078      0.008212
# Epoch 35 elapsed: 0:01:16.22
# Epoch 36/40  Learning rate: 0.002125
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.396079               0.825965      0.008212
# Valid               2.262093               0.769448      0.007647
# Epoch 36 elapsed: 0:01:16.30
# Epoch 37/40  Learning rate: 0.001900
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.289364               0.778832      0.007740
# Valid               2.247146               0.800748      0.007959
# Epoch 37 elapsed: 0:01:16.03
# Epoch 38/40  Learning rate: 0.001675
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.255190               0.768628      0.007639
# Valid               2.380652               0.871513      0.008666
# Epoch 38 elapsed: 0:01:15.97
# Epoch 39/40  Learning rate: 0.001450
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.170440               0.738232      0.007335
# Valid               2.266943               0.834875      0.008301
# Epoch 39 elapsed: 0:01:16.04
# Epoch 40/40  Learning rate: 0.001225
# ------------------------------------------------------------------------------------------------------------------------
#        Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# -------------------------------------------------------------------
# Train               4.131835               0.723067      0.007183
# Valid               2.330542               0.837797      0.008331
# Epoch 40 elapsed: 0:01:16.21
# ------------------------------------------------------------------------------------------------------------------------
#       Energy_RMSE (eV/atom)   Energy_MAE (eV/atom)   Energy_Loss
# ------------------------------------------------------------------
# Test               7.829877               2.184155      0.021794

# %%
# finetune('7net-l3i5', dataset_name='base_dataset_of_eff_shg')
