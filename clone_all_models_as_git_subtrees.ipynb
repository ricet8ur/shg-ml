# %%
# there is no need to execute this cell. These commands are listed here for reproducibility.

# assert these folders are empty first
import os

folders = os.listdir("gnn_cmp")
if len(folders) > 0:
    raise FileExistsError("gnn_cmp is not empty")
# Note: some minor changes could be made to the code of these models during their comparison on the SHG prediction task

# CGCNN
! git subtree add --prefix=gnn_cmp/cgcnn --squash https://github.com/txie-93/cgcnn f42ab233c4ee0c416879d6bc2d22a264418413ad

# ALIGNN
! git subtree add --prefix=gnn_cmp/alignn --squash https://github.com/usnistgov/alignn 5d616626c6e006c074ae5bef4e7469c4d53d13bc
# supports pretrained models provided by authors, but not the latest commit on the moment of writing

# GIN
! git subtree add --prefix=gnn_cmp/SHG-GIN --squash https://github.com/deep-learning-x/SHG-GIN 9c8ba784b562ed427a92605087594dfab96e15d8

# MODNet
! git subtree add --prefix=gnn_cmp/modnet --squash https://github.com/ppdebreuck/modnet 82a6d35002e2c13810bdd24e4ae1ab557713d739

# CHGNet
! git subtree add --prefix=gnn_cmp/chgnet --squash https://github.com/CederGroupHub/chgnet 84e8d55132b2242fad06f9b7f7706b35c1a7da7e

# SevenNet
! git subtree add --prefix=gnn_cmp/SevenNet --squash https://github.com/MDIL-SNU/SevenNet a1fb4c44e767055f822e5e2d3817f4214f65c64b

# MOFTransformer
! git subtree add --prefix=gnn_cmp/MOFTransformer --squash https://github.com/hspark1212/MOFTransformer 13d0fcdd6b4ae3e7fa796f187614895f6691411f
# Out:
# git fetch https://github.com/txie-93/cgcnn f42ab233c4ee0c416879d6bc2d22a264418413ad
# From https://github.com/txie-93/cgcnn
#  * branch                f42ab233c4ee0c416879d6bc2d22a264418413ad -> FETCH_HEAD
# Added dir 'gnn_cmp/cgcnn'
# git fetch https://github.com/usnistgov/alignn 5d616626c6e006c074ae5bef4e7469c4d53d13bc
# From https://github.com/usnistgov/alignn
#  * branch                5d616626c6e006c074ae5bef4e7469c4d53d13bc -> FETCH_HEAD
# Added dir 'gnn_cmp/alignn'
# git fetch https://github.com/deep-learning-x/SHG-GIN 9c8ba784b562ed427a92605087594dfab96e15d8
# From https://github.com/deep-learning-x/SHG-GIN
#  * branch                9c8ba784b562ed427a92605087594dfab96e15d8 -> FETCH_HEAD
# Added dir 'gnn_cmp/SHG-GIN'
# git fetch https://github.com/ppdebreuck/modnet 82a6d35002e2c13810bdd24e4ae1ab557713d739
# From https://github.com/ppdebreuck/modnet
#  * branch                82a6d35002e2c13810bdd24e4ae1ab557713d739 -> FETCH_HEAD
# Added dir 'gnn_cmp/modnet'
# ...
